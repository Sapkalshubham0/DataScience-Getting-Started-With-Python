# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df=pd.read_csv('dm_office_sales.csv')

# %%
df
# Out:
#               division  level of education  training level  work experience  \
# 0             printers        some college               2                6
# 1             printers  associate's degree               2               10
# 2          peripherals         high school               0                9
# 3      office supplies  associate's degree               2                5
# 4      office supplies         high school               1                5
# 5    computer hardware        some college               0               10
# 6          peripherals  associate's degree               0                5
# 7      office supplies        some college               0                6
# 8             printers  associate's degree               3                2
# 9    computer hardware  associate's degree               1                5
# 10            printers  associate's degree               2                3
# ...

# %%
sns.scatterplot(data=df,x='salary',y='sales')

# %%
plt.figure(figsize=(12,6))
sns.scatterplot(data=df,x='salary',y='sales')

# %%
plt.figure(figsize=(12,6))
sns.scatterplot(data=df,x='salary',y='sales',hue='division')

# %%
plt.figure(figsize=(12,6))
sns.scatterplot(data=df,x='salary',y='sales',hue='division',palette='magma')

# %%
plt.figure(figsize=(12,6))
sns.scatterplot(data=df,x='salary',y='sales',hue='training level',palette='magma')

# %%
plt.figure(figsize=(12,6))
sns.scatterplot(data=df,x='salary',y='sales',hue='work experience',palette='plasma')

# %%
plt.figure(figsize=(15,10))
sns.scatterplot(data=df,x='salary',y='sales',style='division',palette='plasma',legend='full')

# %%
plt.figure(figsize=(15,10))
sns.scatterplot(data=df,x='salary',y='sales',style='division',palette='plasma',legend='full',)

# %%
plt.figure(figsize=(15,10))
sns.scatterplot(data=df,x='salary',y='sales',style='division',palette='plasma',legend='full',marker='+')

# %%
plt.figure(figsize=(15,10))
sns.scatterplot(data=df,x='salary',y='sales',style='division',palette='plasma',legend='full')

plt.savefig('scatterplot.png')
