# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('Sales_Funnel_CRM.csv')

# %%
df
# Out:
#     Account Number       Company       Contact Account Manager  \
# 0          2123398        Google   Larry Pager    Edward Thorp
# 1          2123398        Google   Larry Pager    Edward Thorp
# 2          2123398        Google   Larry Pager    Edward Thorp
# 3          2192650          BOBO   Larry Pager    Edward Thorp
# 4           420496          IKEA     Elon Tusk    Edward Thorp
# 5           636685    Tesla Inc.     Elon Tusk    Edward Thorp
# 6           636685    Tesla Inc.     Elon Tusk    Edward Thorp
# 7          1216870     Microsoft   Will Grates    Edward Thorp
# 8          2200450       Walmart   Will Grates    Edward Thorp
# 9           405886         Apple  Cindy Phoner  Claude Shannon
# 10          470248  Exxon Mobile  Cindy Phoner  Claude Shannon
# 11          698032           ATT  Cindy Phoner  Claude Shannon
# 12          698032           ATT  Cindy Phoner  Claude Shannon
# 13          902797    CVS Health  Emma Gordian  Claude Shannon
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 8 columns):
# Account Number     17 non-null int64
# Company            17 non-null object
# Contact            17 non-null object
# Account Manager    17 non-null object
# Product            17 non-null object
# Licenses           17 non-null int64
# Sale Price         17 non-null int64
# Status             17 non-null object
# dtypes: int64(3), object(5)
# memory usage: 1.1+ KB

# %%
df.columns
# Out:
# Index(['Account Number', 'Company', 'Contact', 'Account Manager', 'Product',
#        'Licenses', 'Sale Price', 'Status'],
#       dtype='object')

# %%
df.shape
# Out:
# (17, 8)

# %%
df['Company'].value_counts() #used for categorical data
# Out:
#  Google         3
# Tesla Inc.      2
# Cisco           2
# ATT             2
# Exxon Mobile    1
# Walmart         1
# Apple           1
# Salesforce      1
# BOBO            1
# IKEA            1
# CVS Health      1
# Microsoft       1
# Name: Company, dtype: int64

# %%
df['Status'].value_counts() ##i want to find how many won or lost
# Out:
# Presented       6
# Under Review    4
# Won             4
# Lost            3
# Name: Status, dtype: int64

# %%
df_sum=df.groupby('Company').sum()

# %%
df_sum
# Out:
#               Account Number  Licenses  Sale Price
# Company
#  Google              6370194       600     3150000
# ATT                  1396064       300     1050000
# Apple                 405886       300     4550000
# BOBO                 2192650       150     2450000
# CVS Health            902797       450      490000
# Cisco                4338998       600     4900000
# Exxon Mobile          470248       150     2100000
# IKEA                  420496       300     4550000
# Microsoft            1216870       300      350000
# Salesforce           2046943       750     7000000
# Tesla Inc.           1273370       450     3500000
# Walmart              2200450       150     2450000

# %%
df.groupby('Company').max()['Licenses'].sort_values(ascending=False) # i want to know how many licenses company has in ascending order
# Out:
# Company
# Salesforce      750
# CVS Health      450
# Tesla Inc.      300
# Microsoft       300
# IKEA            300
# Cisco           300
# Apple           300
#  Google         300
# Walmart         150
# Exxon Mobile    150
# BOBO            150
# ATT             150
# Name: Licenses, dtype: int64

# %%
df.groupby('Product').sum()
# Out:
#                  Account Number  Licenses  Sale Price
# Product
# Analytics              12666255      2550    32550000
# GPS Positioning         2169499       300      350000
# Prediction              3458115       450     2100000
# Tracking                4941097      1200     1540000

# %%
##whose average sale price is greater among all companies
df.groupby('Company').mean()['Sale Price']
# Out:
# Company
#  Google         1050000
# ATT              525000
# Apple           4550000
# BOBO            2450000
# CVS Health       490000
# Cisco           2450000
# Exxon Mobile    2100000
# IKEA            4550000
# Microsoft        350000
# Salesforce      7000000
# Tesla Inc.      1750000
# Walmart         2450000
# Name: Sale Price, dtype: int64

# %%
#finding max sales prices by company name

df.groupby('Company').max()['Sale Price'].sort_values(ascending=False)
# Out:
# Company
# Salesforce      7000000
# IKEA            4550000
# Cisco           4550000
# Apple           4550000
# Tesla Inc.      2800000
# Walmart         2450000
# BOBO            2450000
# Exxon Mobile    2100000
#  Google         2100000
# ATT              700000
# CVS Health       490000
# Microsoft        350000
# Name: Sale Price, dtype: int64

# %%
df[df['Product']=='Tracking'] # i want to find product name Tracking Details
# Out:
#     Account Number     Company       Contact Account Manager   Product  \
# 2          2123398      Google   Larry Pager    Edward Thorp  Tracking
# 7          1216870   Microsoft   Will Grates    Edward Thorp  Tracking
# 11          698032         ATT  Cindy Phoner  Claude Shannon  Tracking
# 13          902797  CVS Health  Emma Gordian  Claude Shannon  Tracking
#
#     Licenses  Sale Price        Status
# 2        300      350000  Under Review
# 7        300      350000  Under Review
# 11       150      350000  Under Review
# 13       450      490000           Won

# %%
df['Product'].value_counts() # i want to find what products categories are there
# Out:
# Analytics          9
# Tracking           4
# Prediction         3
# GPS Positioning    1
# Name: Product, dtype: int64

# %%
df.groupby('Company').describe().head()
# Out:
#            Account Number                                                   \
#                     count       mean  std        min        25%        50%
# Company
#  Google               3.0  2123398.0  0.0  2123398.0  2123398.0  2123398.0
# ATT                   2.0   698032.0  0.0   698032.0   698032.0   698032.0
# Apple                 1.0   405886.0  NaN   405886.0   405886.0   405886.0
# BOBO                  1.0  2192650.0  NaN  2192650.0  2192650.0  2192650.0
# CVS Health            1.0   902797.0  NaN   902797.0   902797.0   902797.0
#
#                                  Licenses           ...                    \
#                   75%        max    count   mean    ...        75%    max
# Company                                             ...
#  Google     2123398.0  2123398.0      3.0  200.0    ...      225.0  300.0
# ATT          698032.0   698032.0      2.0  150.0    ...      150.0  150.0
# Apple        405886.0   405886.0      1.0  300.0    ...      300.0  300.0
# ...

# %%
help(pd.pivot)
# Out:
# Help on function pivot_simple in module pandas.core.reshape.reshape:
#
# pivot_simple(index, columns, values)
#     Produce 'pivot' table based on 3 columns of this DataFrame.
#     Uses unique values from index / columns and fills with values.
#
#     Parameters
#     ----------
#     index : ndarray
#         Labels to use to make new frame's index
#     columns : ndarray
#         Labels to use to make new frame's columns
#     values : ndarray
#         Values to use for populating new frame's values
#
#     Notes
#     -----
#     Obviously, all 3 of the input arguments must have the same length
#
#     Returns
#     -------
#     DataFrame
#
#     See also
#     --------
#     DataFrame.pivot_table : generalization of pivot that can handle
#         duplicate values for one index/column pair

# %%
df
# Out:
#     Account Number       Company       Contact Account Manager  \
# 0          2123398        Google   Larry Pager    Edward Thorp
# 1          2123398        Google   Larry Pager    Edward Thorp
# 2          2123398        Google   Larry Pager    Edward Thorp
# 3          2192650          BOBO   Larry Pager    Edward Thorp
# 4           420496          IKEA     Elon Tusk    Edward Thorp
# 5           636685    Tesla Inc.     Elon Tusk    Edward Thorp
# 6           636685    Tesla Inc.     Elon Tusk    Edward Thorp
# 7          1216870     Microsoft   Will Grates    Edward Thorp
# 8          2200450       Walmart   Will Grates    Edward Thorp
# 9           405886         Apple  Cindy Phoner  Claude Shannon
# 10          470248  Exxon Mobile  Cindy Phoner  Claude Shannon
# 11          698032           ATT  Cindy Phoner  Claude Shannon
# 12          698032           ATT  Cindy Phoner  Claude Shannon
# 13          902797    CVS Health  Emma Gordian  Claude Shannon
# ...

# %%
licenses = df[['Company','Product','Licenses','Sale Price']]
licenses
# Out:
#          Company          Product  Licenses  Sale Price
# 0         Google        Analytics       150     2100000
# 1         Google       Prediction       150      700000
# 2         Google         Tracking       300      350000
# 3           BOBO        Analytics       150     2450000
# 4           IKEA        Analytics       300     4550000
# 5     Tesla Inc.        Analytics       300     2800000
# 6     Tesla Inc.       Prediction       150      700000
# 7      Microsoft         Tracking       300      350000
# 8        Walmart        Analytics       150     2450000
# 9          Apple        Analytics       300     4550000
# 10  Exxon Mobile        Analytics       150     2100000
# 11           ATT         Tracking       150      350000
# 12           ATT       Prediction       150      700000
# 13    CVS Health         Tracking       450      490000
# 14    Salesforce        Analytics       750     7000000
# 15         Cisco        Analytics       300     4550000
# ...

# %%
pd.pivot(data=license,index='Company',columns='Product',values='Licenses')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-54-c6fe5d2ecfc3> in <module>()
# ----> 1 pd.pivot(data=license,index='Company',columns='Product',values='Licenses')
#
# TypeError: pivot_simple() got an unexpected keyword argument 'data'

# %%
pd.pivot(data=licenses,index='Company',columns='Product',values='Licenses')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-48-be555a29fe7c> in <module>()
# ----> 1 pd.pivot(data=licenses,index='Company',columns='Product',values='Licenses')
#
# TypeError: pivot_simple() got an unexpected keyword argument 'data'

# %%
df
# Out:
#     Account Number       Company       Contact Account Manager  \
# 0          2123398        Google   Larry Pager    Edward Thorp
# 1          2123398        Google   Larry Pager    Edward Thorp
# 2          2123398        Google   Larry Pager    Edward Thorp
# 3          2192650          BOBO   Larry Pager    Edward Thorp
# 4           420496          IKEA     Elon Tusk    Edward Thorp
# 5           636685    Tesla Inc.     Elon Tusk    Edward Thorp
# 6           636685    Tesla Inc.     Elon Tusk    Edward Thorp
# 7          1216870     Microsoft   Will Grates    Edward Thorp
# 8          2200450       Walmart   Will Grates    Edward Thorp
# 9           405886         Apple  Cindy Phoner  Claude Shannon
# 10          470248  Exxon Mobile  Cindy Phoner  Claude Shannon
# 11          698032           ATT  Cindy Phoner  Claude Shannon
# 12          698032           ATT  Cindy Phoner  Claude Shannon
# 13          902797    CVS Health  Emma Gordian  Claude Shannon
# ...

# %%
a=pd.pivot_table(df,index='Company',aggfunc='sum') # Notice Account Number sum() doesn't make sense to keep/use

# %%
a
# Out:
#               Account Number  Licenses  Sale Price
# Company
#  Google              6370194       600     3150000
# ATT                  1396064       300     1050000
# Apple                 405886       300     4550000
# BOBO                 2192650       150     2450000
# CVS Health            902797       450      490000
# Cisco                4338998       600     4900000
# Exxon Mobile          470248       150     2100000
# IKEA                  420496       300     4550000
# Microsoft            1216870       300      350000
# Salesforce           2046943       750     7000000
# Tesla Inc.           1273370       450     3500000
# Walmart              2200450       150     2450000

# %%
pd.pivot_table(df,index='Company',aggfunc='sum')[['Licenses','Sale Price']] #grab by column names and remove unnecessary data
# Out:
#               Licenses  Sale Price
# Company
#  Google            600     3150000
# ATT                300     1050000
# Apple              300     4550000
# BOBO               150     2450000
# CVS Health         450      490000
# Cisco              600     4900000
# Exxon Mobile       150     2100000
# IKEA               300     4550000
# Microsoft          300      350000
# Salesforce         750     7000000
# Tesla Inc.         450     3500000
# Walmart            150     2450000

# %%
pd.pivot_table(df,index='Company',aggfunc='sum',values=['Licenses','Sale Price']) # or state them as values columns
# Out:
#               Licenses  Sale Price
# Company
#  Google            600     3150000
# ATT                300     1050000
# Apple              300     4550000
# BOBO               150     2450000
# CVS Health         450      490000
# Cisco              600     4900000
# Exxon Mobile       150     2100000
# IKEA               300     4550000
# Microsoft          300      350000
# Salesforce         750     7000000
# Tesla Inc.         450     3500000
# Walmart            150     2450000

# %%
df.groupby('Company').sum()[['Licenses','Sale Price']]
# Out:
#               Licenses  Sale Price
# Company
#  Google            600     3150000
# ATT                300     1050000
# Apple              300     4550000
# BOBO               150     2450000
# CVS Health         450      490000
# Cisco              600     4900000
# Exxon Mobile       150     2100000
# IKEA               300     4550000
# Microsoft          300      350000
# Salesforce         750     7000000
# Tesla Inc.         450     3500000
# Walmart            150     2450000

# %%
pd.pivot_table(df,index=['Account Manager','Contact'],values=['Sale Price'],aggfunc='sum')
# Out:
#                               Sale Price
# Account Manager Contact
# Claude Shannon  Cindy Phoner     7700000
#                 Emma Gordian    12390000
# Edward Thorp    Elon Tusk        8050000
#                 Larry Pager      5600000
#                 Will Grates      2800000

# %%
pd.pivot_table(df,index=['Account Manager','Contact'],values=['Sale Price'],columns=['Product'],aggfunc='sum')
# Out:
#                               Sale Price
# Product                        Analytics GPS Positioning Prediction  Tracking
# Account Manager Contact
# Claude Shannon  Cindy Phoner   6650000.0             NaN   700000.0  350000.0
#                 Emma Gordian  11550000.0        350000.0        NaN  490000.0
# Edward Thorp    Elon Tusk      7350000.0             NaN   700000.0       NaN
#                 Larry Pager    4550000.0             NaN   700000.0  350000.0
#                 Will Grates    2450000.0             NaN        NaN  350000.0

# %%
pd.pivot_table(df,index=['Account Manager','Contact'],values=['Sale Price'],columns=['Product'],aggfunc=[np.sum])
# Out:
#                                      sum
#                               Sale Price
# Product                        Analytics GPS Positioning Prediction  Tracking
# Account Manager Contact
# Claude Shannon  Cindy Phoner   6650000.0             NaN   700000.0  350000.0
#                 Emma Gordian  11550000.0        350000.0        NaN  490000.0
# Edward Thorp    Elon Tusk      7350000.0             NaN   700000.0       NaN
#                 Larry Pager    4550000.0             NaN   700000.0  350000.0
#                 Will Grates    2450000.0             NaN        NaN  350000.0

# %%
pd.pivot_table(df,index=['Account Manager','Contact'],values=['Sale Price'],columns=['Product'],aggfunc=[np.sum],fill_value=0)
# Out:
#                                     sum
#                              Sale Price
# Product                       Analytics GPS Positioning Prediction Tracking
# Account Manager Contact
# Claude Shannon  Cindy Phoner    6650000               0     700000   350000
#                 Emma Gordian   11550000          350000          0   490000
# Edward Thorp    Elon Tusk       7350000               0     700000        0
#                 Larry Pager     4550000               0     700000   350000
#                 Will Grates     2450000               0          0   350000

# %%
#can add multiple agg function
pd.pivot_table(df,index=['Account Manager','Contact'],values=['Sale Price'],columns=['Product'],aggfunc=[np.sum,np.mean],fill_value=0)
# Out:
#                                     sum                                      \
#                              Sale Price
# Product                       Analytics GPS Positioning Prediction Tracking
# Account Manager Contact
# Claude Shannon  Cindy Phoner    6650000               0     700000   350000
#                 Emma Gordian   11550000          350000          0   490000
# Edward Thorp    Elon Tusk       7350000               0     700000        0
#                 Larry Pager     4550000               0     700000   350000
#                 Will Grates     2450000               0          0   350000
#
#                                    mean
#                              Sale Price
# Product                       Analytics GPS Positioning Prediction Tracking
# Account Manager Contact
# Claude Shannon  Cindy Phoner    3325000               0     700000   350000
#                 Emma Gordian    5775000          350000          0   490000
# ...

# %%
#can add on multiple columns and values
pd.pivot_table(df,index=['Account Manager','Contact'],values=['Sale Price','Licenses'],columns=['Product'],aggfunc=[np.sum,],fill_value=0)
# Out:
#                                    sum                                      \
#                               Licenses
# Product                      Analytics GPS Positioning Prediction Tracking
# Account Manager Contact
# Claude Shannon  Cindy Phoner       450               0        150      150
#                 Emma Gordian      1050             300          0      450
# Edward Thorp    Elon Tusk          600               0        150        0
#                 Larry Pager        300               0        150      300
#                 Will Grates        150               0          0      300
#
#
#                              Sale Price
# Product                       Analytics GPS Positioning Prediction Tracking
# Account Manager Contact
# Claude Shannon  Cindy Phoner    6650000               0     700000   350000
#                 Emma Gordian   11550000          350000          0   490000
# Edward Thorp    Elon Tusk       7350000               0     700000        0
# ...

# %%
#can add multiple columns
pd.pivot_table(df,index=['Account Manager','Contact','Product'],values=['Sale Price'],aggfunc=[np.sum,np.mean],fill_value=0)
# Out:
#                                                     sum       mean
#                                              Sale Price Sale Price
# Account Manager Contact      Product
# Claude Shannon  Cindy Phoner Analytics          6650000    3325000
#                              Prediction          700000     700000
#                              Tracking            350000     350000
#                 Emma Gordian Analytics         11550000    5775000
#                              GPS Positioning     350000     350000
#                              Tracking            490000     490000
# Edward Thorp    Elon Tusk    Analytics          7350000    3675000
#                              Prediction          700000     700000
#                 Larry Pager  Analytics          4550000    2275000
#                              Prediction          700000     700000
#                              Tracking            350000     350000
# ...

# %%
# get Final "ALL" with margins = True
# Can add on multiple columns
pd.pivot_table(df,index=["Account Manager","Contact","Product"],values=["Sale Price","Licenses"],
               aggfunc=[np.sum],fill_value=0,margins=True)
# Out:
#                                                   sum
#                                              Licenses Sale Price
# Account Manager Contact      Product
# Claude Shannon  Cindy Phoner Analytics            450    6650000
#                              Prediction           150     700000
#                              Tracking             150     350000
#                 Emma Gordian Analytics           1050   11550000
#                              GPS Positioning      300     350000
#                              Tracking             450     490000
# Edward Thorp    Elon Tusk    Analytics            600    7350000
#                              Prediction           150     700000
#                 Larry Pager  Analytics            300    4550000
#                              Prediction           150     700000
#                              Tracking             300     350000
#                 Will Grates  Analytics            150    2450000
# ...

# %%
pd.pivot_table(df,index=["Account Manager","Status"],values=["Sale Price"],
               aggfunc=[np.sum],fill_value=0,margins=True)
# Out:
#                                     sum
#                              Sale Price
# Account Manager Status
# Claude Shannon  Lost            4550000
#                 Presented       3150000
#                 Under Review     350000
#                 Won            12040000
# Edward Thorp    Lost            4900000
#                 Presented       3500000
#                 Under Review    3500000
#                 Won             4550000
# All                            36540000

# %%
a=pd.pivot_table(df,index='Company',aggfunc='sum')

# %%
a
# Out:
#               Account Number  Licenses  Sale Price
# Company
#  Google              6370194       600     3150000
# ATT                  1396064       300     1050000
# Apple                 405886       300     4550000
# BOBO                 2192650       150     2450000
# CVS Health            902797       450      490000
# Cisco                4338998       600     4900000
# Exxon Mobile          470248       150     2100000
# IKEA                  420496       300     4550000
# Microsoft            1216870       300      350000
# Salesforce           2046943       750     7000000
# Tesla Inc.           1273370       450     3500000
# Walmart              2200450       150     2450000

# %%
a=pd.pivot_table(df,index=['Account Manager','Contact'],values=['Sale Price'],aggfunc='sum')

# %%
a
# Out:
#                               Sale Price
# Account Manager Contact
# Claude Shannon  Cindy Phoner     7700000
#                 Emma Gordian    12390000
# Edward Thorp    Elon Tusk        8050000
#                 Larry Pager      5600000
#                 Will Grates      2800000
