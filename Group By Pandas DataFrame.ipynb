# %%
import numpy as np
import pandas as pd

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\test\\Desktop\\Python\\Untitled Folder'

# %%
help(pd.groupby)
# Out:
# Help on function groupby in module pandas.core.api:
#
# groupby(*args, **kwargs)

# %%
df=pd.read_csv('mpg.csv')

# %%
df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model_year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
df.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model_year', 'origin', 'name'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
# mpg             398 non-null float64
# cylinders       398 non-null int64
# displacement    398 non-null float64
# horsepower      398 non-null object
# weight          398 non-null int64
# acceleration    398 non-null float64
# model_year      398 non-null int64
# origin          398 non-null int64
# name            398 non-null object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.1+ KB

# %%
df.shape
# Out:
# (398, 9)

# %% [markdown]
# Aggregating functions are the ones that reduce the dimension of the returned objects. Some common aggregating functions are tabulated below:
#
# Function
#
#
# Description
#
# mean()
#
#
# Compute mean of groups
#
# sum()
#
#
# Compute sum of group values
#
# size()
#
#
# Compute group sizes
#
# count()
#
#
# Compute count of group
#
# std()
#
#
# Standard deviation of groups
#
# var()
#
#
# Compute variance of groups
#
# sem()
#
#
# Standard error of the mean of groups
#
# describe()
#
#
# Generates descriptive statistics
#
# first()
#
#
# Compute first of group values
#
# last()
#
#
# Compute last of group values
#
# nth()
#
#
# Take nth value, or a subset if n is a list
#
# min()
#
#
# Compute min of group values
#
# max()
#
#
# Compute max of group values
#
# The aggregating functions above will exclude NA values. Any function which reduces a Series to a scalar value is an aggregation function and will work, a trivial example is df.groupby('A').agg(lambda ser: 1). Note that nth() can act as a reducer or a filter, see here.

# %%
df.groupby('model_year').mean()
# Out:
#                   mpg  cylinders  displacement       weight  acceleration  \
# model_year
# 70          17.689655   6.758621    281.413793  3372.793103     12.948276
# 71          21.250000   5.571429    209.750000  2995.428571     15.142857
# 72          18.714286   5.821429    218.375000  3237.714286     15.125000
# 73          17.100000   6.375000    256.875000  3419.025000     14.312500
# 74          22.703704   5.259259    171.740741  2877.925926     16.203704
# 75          20.266667   5.600000    205.533333  3176.800000     16.050000
# 76          21.573529   5.647059    197.794118  3078.735294     15.941176
# 77          23.375000   5.464286    191.392857  2997.357143     15.435714
# 78          24.061111   5.361111    177.805556  2861.805556     15.805556
# 79          25.093103   5.827586    206.689655  3055.344828     15.813793
# 80          33.696552   4.137931    115.827586  2436.655172     16.934483
# ...

# %%
df.groupby('model_year').sum()
# Out:
#               mpg  cylinders  displacement  weight  acceleration  origin
# model_year
# 70          513.0        196        8161.0   97811         375.5      38
# 71          595.0        156        5873.0   83872         424.0      40
# 72          524.0        163        6114.5   90656         423.5      43
# 73          684.0        255       10275.0  136761         572.5      55
# 74          613.0        142        4637.0   77704         437.5      45
# 75          608.0        168        6166.0   95304         481.5      44
# 76          733.5        192        6725.0  104677         542.0      50
# 77          654.5        153        5359.0   83926         432.2      44
# 78          866.2        193        6401.0  103025         569.0      58
# 79          727.7        169        5994.0   88605         458.6      37
# 80          977.2        120        3359.0   70663         491.1      64
# 81          879.7        134        3924.0   73165         472.9      57
# ...

# %%
df.groupby('model_year').min()
# Out:
#              mpg  cylinders  displacement horsepower  weight  acceleration  \
# model_year
# 70           9.0          4          97.0        113    1835           8.0
# 71          12.0          4          71.0        100    1613          11.5
# 72          11.0          3          70.0        112    2100          11.0
# 73          11.0          3          68.0        100    1867           9.5
# 74          13.0          4          71.0        100    1649          13.5
# 75          13.0          4          90.0        100    1795          11.5
# 76          13.0          4          85.0        100    1795          12.0
# 77          15.0          3          79.0        100    1825          11.1
# 78          16.2          4          78.0        100    1800          11.2
# 79          15.5          4          85.0        110    1915          11.3
# 80          19.1          3          70.0        100    1835          11.4
# ...

# %%
df.groupby('model_year').count()
# Out:
#             mpg  cylinders  displacement  horsepower  weight  acceleration  \
# model_year
# 70           29         29            29          29      29            29
# 71           28         28            28          28      28            28
# 72           28         28            28          28      28            28
# 73           40         40            40          40      40            40
# 74           27         27            27          27      27            27
# 75           30         30            30          30      30            30
# 76           34         34            34          34      34            34
# 77           28         28            28          28      28            28
# 78           36         36            36          36      36            36
# 79           29         29            29          29      29            29
# 80           29         29            29          29      29            29
# ...

# %%
df.groupby('model_year').std()
# Out:
#                  mpg  cylinders  displacement       weight  acceleration  \
# model_year
# 70          5.339231   1.724926    124.421380   852.868663      3.330982
# 71          6.591942   1.665079    115.102410  1061.830859      2.666171
# 72          5.435529   2.073708    123.781964   974.520960      2.850032
# 73          4.700245   1.807215    121.722085   974.809133      2.754222
# 74          6.420010   1.583390     92.601127   949.308571      1.688532
# 75          4.940566   1.522249     87.669730   765.179781      2.471737
# 76          5.889297   1.667558     94.422256   821.371481      2.801419
# 77          6.675862   1.815206    107.813742   912.825902      2.273391
# 78          6.898044   1.495761     76.012713   626.023907      2.129915
# 79          6.794217   1.774199     96.307581   747.881497      2.952931
# 80          7.037983   0.580895     33.744914   432.235491      2.826694
# 81          5.591465   1.082781     58.387929   533.600501      2.192509
# ...

# %%
df.groupby('model_year').var()
# Out:
#                   mpg  cylinders  displacement        weight  acceleration  \
# model_year
# 70          28.507389   2.975369  15480.679803  7.273850e+05     11.095443
# 71          43.453704   2.772487  13248.564815  1.127485e+06      7.108466
# 72          29.544974   4.300265  15321.974537  9.496911e+05      8.122685
# 73          22.092308   3.266026  14816.266026  9.502528e+05      7.585737
# 74          41.216524   2.507123   8574.968661  9.011868e+05      2.851140
# 75          24.409195   2.317241   7685.981609  5.855001e+05      6.109483
# 76          34.683824   2.780749   8915.562389  6.746511e+05      7.847950
# 77          44.567130   3.294974  11623.802910  8.332511e+05      5.168307
# 78          47.583016   2.237302   5777.932540  3.919059e+05      4.536540
# 79          46.161379   3.147783   9275.150246  5.593267e+05      8.719803
# 80          49.533202   0.337438   1138.719212  1.868275e+05      7.990197
# ...

# %%
df.groupby('model_year').first()
# Out:
#              mpg  cylinders  displacement horsepower  weight  acceleration  \
# model_year
# 70          18.0          8         307.0        130    3504          12.0
# 71          27.0          4          97.0         88    2130          14.5
# 72          24.0          4         113.0         95    2278          15.5
# 73          13.0          8         350.0        175    4100          13.0
# 74          20.0          6         198.0         95    3102          16.5
# 75          19.0          6         225.0         95    3264          16.0
# 76          28.0          4         107.0         86    2464          15.5
# 77          31.5          4          98.0         68    2045          18.5
# 78          43.1          4          90.0         48    1985          21.5
# 79          21.5          6         231.0        115    3245          15.4
# 80          41.5          4          98.0         76    2144          14.7
# ...

# %%
df.groupby('model_year').last()
# Out:
#              mpg  cylinders  displacement horsepower  weight  acceleration  \
# model_year
# 70           9.0          8         304.0        193    4732          18.5
# 71          26.0          4          91.0         70    1955          20.5
# 72          27.0          4          97.0         88    2100          16.5
# 73          11.0          8         350.0        180    3664          11.0
# 74          31.0          4          79.0         67    2000          16.0
# 75          33.0          4          91.0         53    1795          17.5
# 76          13.0          8         318.0        150    3755          14.0
# 77          21.5          3          80.0        110    2720          13.5
# 78          29.5          4          98.0         68    2135          16.6
# 79          33.5          4         151.0         90    2556          13.2
# 80          32.4          4         107.0         72    2290          17.0
# ...

# %%
df.groupby('model_year').max()[['mpg','acceleration']]
# Out:
#              mpg  acceleration
# model_year
# 70          27.0          20.5
# 71          35.0          20.5
# 72          28.0          23.5
# 73          29.0          21.0
# 74          32.0          21.0
# 75          33.0          21.0
# 76          33.0          22.2
# 77          36.0          19.0
# 78          43.1          21.5
# 79          37.3          24.8
# 80          46.6          23.7
# 81          39.1          20.7
# 82          44.0          24.6

# %%
df.groupby('model_year').min()[['mpg','weight']]
# Out:
#              mpg  weight
# model_year
# 70           9.0    1835
# 71          12.0    1613
# 72          11.0    2100
# 73          11.0    1867
# 74          13.0    1649
# 75          13.0    1795
# 76          13.0    1795
# 77          15.0    1825
# 78          16.2    1800
# 79          15.5    1915
# 80          19.1    1835
# 81          17.6    1755
# 82          22.0    1965

# %%
avg_year = df.groupby('model_year').mean()

# %%
avg_year.index
# Out:
# Int64Index([70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82], dtype='int64', name='model_year')

# %%
avg_year.index[-1]
# Out:
# 82

# %%
avg_year.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'weight', 'acceleration', 'origin'], dtype='object')

# %%
avg_year['mpg']
# Out:
# model_year
# 70    17.689655
# 71    21.250000
# 72    18.714286
# 73    17.100000
# 74    22.703704
# 75    20.266667
# 76    21.573529
# 77    23.375000
# 78    24.061111
# 79    25.093103
# 80    33.696552
# 81    30.334483
# 82    31.709677
# Name: mpg, dtype: float64

# %%
df.groupby('model_year').mean()['mpg']
# Out:
# model_year
# 70    17.689655
# 71    21.250000
# 72    18.714286
# 73    17.100000
# 74    22.703704
# 75    20.266667
# 76    21.573529
# 77    23.375000
# 78    24.061111
# 79    25.093103
# 80    33.696552
# 81    30.334483
# 82    31.709677
# Name: mpg, dtype: float64

# %%
df.groupby('model_year').describe()
# Out:
#            acceleration                                                    \
#                   count       mean       std   min     25%    50%     75%
# model_year
# 70                 29.0  12.948276  3.330982   8.0  10.000  12.50  15.000
# 71                 28.0  15.142857  2.666171  11.5  13.375  14.50  16.125
# 72                 28.0  15.125000  2.850032  11.0  13.375  14.50  16.625
# 73                 40.0  14.312500  2.754222   9.5  12.500  14.00  16.000
# 74                 27.0  16.203704  1.688532  13.5  15.250  16.00  17.000
# 75                 30.0  16.050000  2.471737  11.5  14.125  16.00  17.375
# 76                 34.0  15.941176  2.801419  12.0  13.925  15.50  17.550
# 77                 28.0  15.435714  2.273391  11.1  14.000  15.65  16.925
# 78                 36.0  15.805556  2.129915  11.2  14.475  15.75  16.825
# 79                 29.0  15.813793  2.952931  11.3  14.000  15.00  17.300
# ...

# %%
d=df.groupby('model_year').describe().transpose()
d.to_csv('mpg1.csv')

# %%
#find average weight when year is 70 and cylinders 8
df.groupby(['model_year','cylinders']).mean()
# Out:
#                             mpg  displacement       weight  acceleration  \
# model_year cylinders
# 70         4          25.285714    107.000000  2292.571429     16.000000
#            6          20.500000    199.000000  2710.500000     15.500000
#            8          14.111111    367.555556  3940.055556     11.194444
# 71         4          27.461538    101.846154  2056.384615     16.961538
#            6          18.000000    243.375000  3171.875000     14.750000
#            8          13.428571    371.714286  4537.714286     12.214286
# 72         3          19.000000     70.000000  2330.000000     13.500000
#            4          23.428571    111.535714  2382.642857     17.214286
#            8          13.615385    344.846154  4228.384615     13.000000
# 73         3          18.000000     70.000000  2124.000000     13.500000
#            4          22.727273    109.272727  2338.090909     17.136364
# ...

# %%
df.groupby(['model_year','cylinders']).max()['weight'][80] #finding maximum weight in year 80 and cylinder are 6
# Out:
# cylinders
# 3    2420
# 4    3250
# 5    2950
# 6    3381
# Name: weight, dtype: int64

# %%
df.groupby(['model_year','acceleration']).min()
# Out:
#                           mpg  cylinders  displacement horsepower  weight  \
# model_year acceleration
# 70         8.0           14.0          8         340.0        160    3609
#            8.5           14.0          8         390.0        190    3850
#            9.0           14.0          8         454.0        220    4354
#            9.5           15.0          8         400.0        150    3761
#            10.0          14.0          8         383.0        170    3086
#            10.5          17.0          8         302.0        140    3449
#            11.0          18.0          8         318.0        150    3436
#            11.5          15.0          8         350.0        165    3693
#            12.0          16.0          8         304.0        130    3433
#            12.5          26.0          4         121.0        113    2234
#            13.5          11.0          8         318.0        210    4382
# ...

# %%
df.groupby(['model_year','cylinders']).agg([np.max,np.mean,np.min])
# Out:
#                        mpg                  displacement                     \
#                       amax       mean  amin         amax        mean   amin
# model_year cylinders
# 70         4          27.0  25.285714  24.0        121.0  107.000000   97.0
#            6          22.0  20.500000  18.0        200.0  199.000000  198.0
#            8          18.0  14.111111   9.0        455.0  367.555556  302.0
# 71         4          35.0  27.461538  22.0        140.0  101.846154   71.0
#            6          19.0  18.000000  16.0        258.0  243.375000  225.0
#            8          14.0  13.428571  12.0        400.0  371.714286  318.0
# 72         3          19.0  19.000000  19.0         70.0   70.000000   70.0
#            4          28.0  23.428571  18.0        140.0  111.535714   96.0
#            8          17.0  13.615385  11.0        429.0  344.846154  302.0
# 73         3          18.0  18.000000  18.0         70.0   70.000000   70.0
# ...
